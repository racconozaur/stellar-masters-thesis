# %%
import sys
print(sys.version)
# Out:
# 3.9.2 (default, Mar 20 2025, 02:07:39)
# [GCC 10.2.1 20210110]

# %%
import numpy as np
import pandas as pd
import scipy
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("SciPy:", scipy.__version__)
# Out:
# NumPy: 2.0.2
# Pandas: 2.3.0+4.g1dfc98e16a
# SciPy: 1.13.1

# %%
import networkx as nx
print("NetworkX:", nx.__version__)
# Out:
# NetworkX: 3.2.1

# %%
import node2vec
print("node2vec version:", node2vec.__version__)
# Out:
# node2vec version: 0.5.0

# %%
import sklearn
print("scikit-learn version:", sklearn.__version__)
# Out:
# scikit-learn version: 1.6.1
